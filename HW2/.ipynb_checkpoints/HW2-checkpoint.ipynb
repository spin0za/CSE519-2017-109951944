# %%
import pandas as pd
import numpy as np
# import scipy.stats as sps
import seaborn as sns
import matplotlib.pyplot as plt
# import matplotlib.dates as mdates
# %matplotlib notebook
import random as rd
# import datetime as dt

# %%
# read original data save to a faster format
df = pd.read_csv('properties_2016.csv', low_memory=False)
df.to_pickle('properties_2016.pkl')

# %%
# initialize
raw = pd.read_pickle('properties_2016.pkl')
df = raw

# %%
# cleaning
# delete entries where room number = 0, not realistic
roomcnts = [col for col in df if 'roomcnt' in col]
df[roomcnts] = df[roomcnts].replace(0.0, np.nan)

# drop empty records(rows)
df.drop('parcelid', axis=1, inplace=True)
df.dropna(how='all', inplace=True)

# drop categorical data
# NOTE: building quality id has numeric meaning!
keyword = ['id', 'fips', 'census', 'property']
df.drop([col for col in df if any(w in col for w in keyword)], axis=1, inplace=True)

# drop columns with 90% missing
df.drop([col for col in df if df[col].count() / df.shape[0] < .1], axis=1, inplace=True)

# drop columns with almost constant value
df.drop([col for col in df if df[col].value_counts().iloc[0] / df[col].count() > .95], axis=1, inplace=True)

# %%
df.count()
# Out:
# bathroomcnt                     2857141
# bedroomcnt                      2852301
# calculatedbathnbr               2856305
# calculatedfinishedsquarefeet    2929652
# finishedsquarefeet12            2709184
# fireplacecnt                     312637
# fullbathcnt                     2856305
# garagecarcnt                     883267
# garagetotalsqft                  883267
# latitude                        2973780
# longitude                       2973780
# lotsizesquarefeet               2709118
# roomcnt                          664863
# unitcnt                         1977490
# yearbuilt                       2925289
# numberofstories                  682069
# structuretaxvaluedollarcnt      2930235
# taxvaluedollarcnt               2942667
# landtaxvaluedollarcnt           2917484
# taxamount                       2953967
# dtype: int64

# %%
corrmat = df.corr()

# %%
plt.subplots()
sns.heatmap(corrmat, cmap='bwr', xticklabels=True, yticklabels=True)
plt.yticks(rotation=0);
plt.xticks(rotation=90);
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="794">

# %%
# line chart
plt.subplots()
x = 'yearbuilt'; y = 'buildingqualitytypeid'
df.groupby([x])[y].mean().plot()
plt.xlabel(x); plt.ylabel(y)
plt.title('Figure 2.1')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="549">

# %%
# line chart
plt.subplots()
x = 'yearbuilt'; y = 'number of houses'
df.groupby([x])[x].count().plot()
plt.xlabel(x); plt.ylabel(y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="549">

# %%
# scatter plot
plt.subplots()
sample = rd.sample(range(df.shape[0]), 1000)
x = 'longitude'; y = 'latitude'; z = ' (°)'
plt.scatter(df[x][sample] / 1e6, df[y][sample] / 1e6, s=5)
plt.xlabel(x + z); plt.ylabel(y + z)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="572">

# %%
# histogram
plt.subplots()
x = 'airconditioningtypeid'; y = 'number of houses'
df[x].dropna().plot(kind='hist')
plt.xlabel(x); plt.ylabel(y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="581">

# %%
# 3. linear regression
train = pd.read_csv('train_2016_v2.csv', low_memory=False)
dflr = pd.merge(df, train, on='parcelid')

# %%
lrcor = dflr.corr()

# %%
plt.subplots()
sns.heatmap(lrcor, cmap='bwr', xticklabels=True, yticklabels=True)
plt.yticks(rotation=0);
plt.xticks(rotation=90);
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="986">
